# %%
from utils.datasets import LoadStreams, LoadImages, LoadOtherImages, LoadNorwayImages
from torch.utils.data import IterableDataset
from torch.utils.data import DataLoader
class IteratorDataset(IterableDataset):
    def __init__(self, iterator):
        self.iterator = iterator
    
    def __iter__(self):
        return self.iterator

# %%
path = '/home/pham/Documents/SHSU/Researching/roaddamagedetector/RDD2022_0/Norway/test/images'
dataset = LoadNorwayImages(path)
for path, img, im0s, origsize in dataset:
  print(origsize)
  print(img.shape)
  print(im0s.shape)
  print(path)
  break
# Out:
# (2044, 3650)
# (3, 960, 960)
# (1824, 1824, 3)
# /home/pham/Documents/SHSU/Researching/roaddamagedetector/RDD2022_0/Norway/test/images/Norway_008161.jpg

# %%
import matplotlib.pyplot as plt
plt.imshow(img.transpose(1, 2, 0))
plt.show()
plt.imshow(im0s[:,:,::-1])
plt.show()

# %%
path = '/home/pham/Documents/SHSU/Researching/roaddamagedetector/RDD2022_0/Norway/test/images'
dataset = LoadOtherImages(path)
len(dataset)
# Out:
# 0

# %%
class A():
  def __init__(self, x):
    self.x = x

a = A(10)
type(a)
# Out:
# __main__.A

# %%
a.__class__.__name__
# Out:
# 'A'
